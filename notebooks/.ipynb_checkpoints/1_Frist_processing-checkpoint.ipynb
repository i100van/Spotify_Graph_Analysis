# %%
import pandas as pd
import numpy as np
import ast
import networkx as nx
import matplotlib.pyplot as plt
#from pyvis.network import Network

# %%
df=pd.read_csv('../data/data.csv')

def is_duo(x):
    arts=ast.literal_eval(x)
    if len(arts)>1:
        return True
    else:
        return False
    
#Marcamos aquellas canciones que sean colaboraciones    
df['is_colab']=df['artists'].apply(lambda x:is_duo(x))
#Seleccionamos las colabs y de popularidad mayor, por disminuir el dataset
df=df[(df.is_colab==True) & (df.popularity>75)].drop(['id','mode','is_colab'],axis=1)

# %%
df.shape
# Out:
# (470, 17)

# %%
def get_artist_list(lista):
    res=set()
    for x in lista:
        arts=ast.literal_eval(x)
        for i in arts:
            res.add(i)
    return list(res)

def look_up(artist,df):
    res=list()
    for ind in df.index:
        d = list(df.loc[ind])
        if (artist in ast.literal_eval(d[1])):
            del d[1],d[6],d[8],d[9]
            res.append(d)
    return res

def create_nodes_meta(df):
    lista_artistas=get_artist_list(df.artists)
    new_df=pd.DataFrame(lista_artistas)
    res=list()
    for artist_x in lista_artistas:
        a_data=look_up(artist_x,df)
        a_means= np.nanmean(a_data,axis=0)
        data=np.concatenate(([artist_x],a_means))
        res.append(data)
    new_df=pd.DataFrame(res)
    new_df.columns=['artist','acousticness', 'danceability', 'duration_ms', 'energy',
       'explicit', 'instrumentalness', 'liveness', 'loudness',
       'popularity', 'speechiness', 'tempo', 'valence',
       'year']
    return new_df
    
df_artist=df.copy()
df_artist=create_nodes_meta(df_artist)

# %%
df_artist
# Out:
#                  artist         acousticness        danceability  \
# 0               Normani                 0.45               0.741
# 1                 Diplo              0.10522  0.6587500000000001
# 2              Octavian                0.185               0.866
# 3                   DDG               0.0614               0.928
# 4                  Zedd  0.26733333333333337  0.7236666666666666
# ..                  ...                  ...                 ...
# 513               NEIMY                 0.27               0.659
# 514        Taylor Swift   0.5072666666666668  0.5186666666666667
# 515  Norma Jean Martine               0.0247  0.7979999999999999
# 516        Social House               0.3895              0.5845
# 517        Charlie Puth                0.369  0.6890000000000001
#
#             duration_ms              energy explicit       instrumentalness  \
# 0              171030.0                0.52      0.0               1.97e-06
# 1              171662.5  0.6592500000000001      0.5               4.08e-05
# 2              161668.0               0.563      1.0                    0.0
# 3              170233.0               0.341      1.0                    0.0
# 4    192234.33333333334  0.6316666666666667      0.0                    0.0
# ..                  ...                 ...      ...                    ...
# 513            164010.0               0.615      0.0                    0.0
# 514  253474.66666666666              0.5125      0.0  0.0005416333333333333
# 515            156960.0               0.828      0.0               2.55e-06
# 516            175373.5               0.637      0.5                    0.0
# 517            229526.0               0.481      0.0               1.03e-06
#
#                 liveness             loudness         popularity  \
# 0                  0.222               -7.513               81.0
# 1               0.125075              -6.0105               76.5
# 2                 0.0889               -6.964               82.0
# 3                  0.162              -10.196               83.0
# 4                  0.111  -4.1080000000000005               78.0
# ..                   ...                  ...                ...
# 513                0.187               -5.865               76.0
# 514  0.12066666666666666   -8.412833333333333  79.66666666666667
# 515                0.121                -5.36               81.0
# 516               0.1252               -4.535               79.0
# 517               0.0649   -7.502999999999999               81.0
#
#               speechiness               tempo              valence  \
# 0                  0.0656             102.998  0.34700000000000003
# 1                 0.08015           132.92025              0.52325
# 2                   0.108             127.954                0.307
# 3                   0.103             129.966                0.745
# 4                  0.0572             103.004  0.49633333333333335
# ..                    ...                 ...                  ...
# 513                0.0644             119.843                0.193
# 514  0.043000000000000003  114.63683333333334   0.3554999999999999
# 515                 0.193             124.962                  0.6
# 516               0.24975             143.074               0.7525
# 517                0.0815              80.025  0.28300000000000003
#
#                    year
# 0                2019.0
# 1               2019.75
# 2                2020.0
# 3                2020.0
# 4                2017.0
# ..                  ...
# 513              2018.0
# 514  2019.3333333333333
# 515              2020.0
# 516              2018.5
# 517              2015.0
#
# [518 rows x 14 columns]

# %%
def add_nodes(df,graph):
    for ind in df.index:
        row=list(df.loc[ind])
        artist_x=row[0]
        graph.add_node(artist_x)
        for i,col in enumerate(df.columns):
            if col != 'artist':
                graph.nodes[artist_x][col]=row[i]
    return graph
    
def add_nodes_edges(df,df_artist,G):
    G=add_nodes(df_artist,G)
    for ind in df.index:
        artists=df.loc[ind]['artists'].strip('][').split(', ')
        artists=[art.replace("'","") for art in artists] 
        for i in range(len(artists)-1):
            G.add_edge(artists[i],artists[i+1])
            for column in df_artist.columns:
                if column != 'artist':
                    G[artists[i]][artists[i+1]][column]=df.loc[ind][column]
    return G

def add_attributes(G,d,name):
    for k,v in d.items():
        G.nodes[k][name]=v
    return G

G = nx.Graph()
G = add_nodes_edges(df,df_artist,G)

# %%
G.number_of_nodes(),G.number_of_edges()
# Out:
# (525, 575)

# %%
from networkx.algorithms import approximation as approx
approx.node_connectivity(G)
# Out:
# 0

# %%
from networkx.algorithms import approximation as apxa
apxa.k_components(G)
# Out:
# defaultdict(list,
#             {1: [{'2 Chainz',
#                '21 Savage',
#                '24kGoldn',
#                '42 Dugg',
#                '50 Cent',
#                '6ix9ine',
#                'A Boogie Wit da Hoodie',
#                'A$AP Rocky',
#                'ABRA',
#                'Afrojack',
#                'Alan Walker',
#                'Alessia Cara',
#                'Alesso',
#                'Alex Rose',
#                'Alicia Keys',
#                'All Time Low',
#                'Anne-Marie',
#                'Anuel AA',
#                'Arcangel',
#                'Ariana Grande',
#                'Ava Max',
#                'BLACKPINK',
#                'BTS',
#                'Bad Bunny',
#                'Bankrol Hayden',
#                'Bastille',
#                'Bazzi',
#                'Bebe Rexha',
#                'Becky Hill',
#                'Beyoncé',
#                'Big Sean',
#                'Billie Eilish',
#                'Black Eyed Peas',
#                'Bon Iver',
#                'Bradley Cooper',
#                'Brendon Urie',
#                'Brray',
#                'Bruno Mars',
#                'Bryant Myers',
#                'Bryson Tiller',
#                'CHVRCHES',
#                'Calvin Harris',
#                'Camila Cabello',
#                'Camilo',
#                'Cardi B',
#                'Casper Magico',
#                'Cazzu',
#                'Chance the Rapper',
#                'Charlie Puth',
#                'Chencho Corleone',
#                'Chris Brown',
#                'Christian Nodal',
#                'City Girls',
#                'Clean Bandit',
#                'Coldplay',
#                'Conan Gray',
#                'DJ Khaled',
#                'DJ Nelson',
#                'DJ Snake',
#                'DaBaby',
#                'Daddy Yankee',
#                'Daft Punk',
#                'Dalex',
#                'Dan + Shay',
#                'Dan Caplen',
#                'Daniel Caesar',
#                'Darell',
#                'Daya',
#                'Demi Lovato',
#                'Dermot Kennedy',
#                'Dido',
#                'Diplo',
#                'Disciples',
#                'Disclosure',
#                'Dixie D’Amelio',
#                'Doja Cat',
#                'Don Toliver',
#                'Dr. Dre',
#                'Drake',
#                'Dua Lipa',
#                'Dwele',
#                'Dímelo Flow',
#                'Ed Sheeran',
#                'El Alfa',
#                'El Guincho',
#                'Ellie Goulding',
#                'Eminem',
#                'Estelle',
#                'FKJ',
#                'Fall Out Boy',
#                'Farruko',
#                'Fifth Harmony',
#                'Flo Rida',
#                'Florida Georgia Line',
#                'Flow La Movie',
#                'French Montana',
#                'Freshlyground',
#                'Funk Wav',
#                'Future',
#                'G Herbo',
#                'G-Eazy',
#                'Giveon',
#                'Goodboys',
#                'Grey',
#                'Gucci Mane',
#                'Gunna',
#                'H.E.R.',
#                'HAIM',
#                'HVME',
#                'Hailee Steinfeld',
#                'Halsey',
#                'Hozier',
#                'ILLENIUM',
#                'Imagine Dragons',
#                'Imanbek',
#                'Internet Money',
#                'Ir Sais',
#                'J Balvin',
#                'JACKBOYS',
#                'JAY-Z',
#                'Jack Harlow',
#                'Jamie Foxx',
#                'Jason Derulo',
#                'Jawsh 685',
#                'Jay Rock',
#                'Jay Sean',
#                'Jay Wheeler',
#                'Jess Glynne',
#                'Jessie J',
#                'Jessie Reyez',
#                'Jhay Cortez',
#                'Jhené Aiko',
#                'Joji',
#                'Jonas Brothers',
#                'Jowell & Randy',
#                'Juanka',
#                'Juhn',
#                'Juice WRLD',
#                'Justin Bieber',
#                'Justin Quiles',
#                'KAROL G',
#                'KEVVO',
#                'Kacey Musgraves',
#                'Kacy Hill',
#                'Kali Uchis',
#                'Kane Brown',
#                'Kanye West',
#                'Kehlani',
#                'Kelsea Ballerini',
#                'Kendo Kaponi',
#                'Kendrick Lamar',
#                'Kesha',
#                'Kevin Roldan',
#                'Khalid',
#                'Kid Cudi',
#                'King Von',
#                'Kodak Black',
#                'Kyla',
#                'LSD',
#                'Labrinth',
#                'Lady Gaga',
#                'Lauv',
#                'Lennon Stella',
#                'Lenny Tavárez',
#                'Liam Payne',
#                'Lil Baby',
#                'Lil Durk',
#                'Lil Jon',
#                'Lil Mosey',
#                'Lil Peep',
#                'Lil Tecca',
#                'Lil Tjay',
#                'Lil Tracy',
#                'Lil Uzi Vert',
#                'Lil Wayne',
#                'Lil Yachty',
#                'Little Mix',
#                'Liz Gillies',
#                'Lizzo',
#                'Logic',
#                'Los Legendarios',
#                'Ludacris',
#                'Luis Fonsi',
#                'Lunay',
#                'Lyanno',
#                'M.I.A.',
#                'MEDUZA',
#                'Machine Gun Kelly',
#                'Macklemore',
#                'Maluma',
#                'Manuel Turizo',
#                'Marc Anthony',
#                'Maren Morris',
#                'Mark Ronson',
#                'Marshmello',
#                'Martin Garrix',
#                'Masego',
#                'Meek Mill',
#                'Megan Thee Stallion',
#                'Metro Boomin',
#                'Micro TDH',
#                'Migos',
#                'Mike WiLL Made-It',
#                'Miley Cyrus',
#                'Money Man',
#                'Moneybagg Yo',
#                'Mora',
#                'Morgan Wallen',
#                'Mustard',
#                'Myke Towers',
#                'NAV',
#                'NLE Choppa',
#                'Nate Dogg',
#                'Nayer',
#                'Ne-Yo',
#                'Nicki Minaj',
#                'Nicky Jam',
#                'Nile Rodgers',
#                'Nio Garcia',
#                'Normani',
#                'Nuka',
#                'Octavian',
#                'Offset',
#                'Oh Wonder',
#                'Olivia',
#                'Ozuna',
#                'Ozzy Osbourne',
#                'PARTYNEXTDOOR',
#                'Panic! At The Disco',
#                'Paul McCartney',
#                'Pharrell Williams',
#                'Piso 21',
#                'Pitbull',
#                'Playboi Carti',
#                'Polo G',
#                'Pooh Shiesty',
#                'Pop Smoke',
#                'Popp Hunna',
#                'Post Malone',
#                'Quavo',
#                'RAYE',
#                'ROSALÍA',
#                'Rafa Pabön',
#                'Rauw Alejandro',
#                'Regard',
#                'Rick Ross',
#                'Rihanna',
#                'Rod Wave',
#                'Roddy Ricch',
#                'Romeo Santos',
#                'Roy Woods',
#                'Rudimental',
#                'SZA',
#                'Sabrina Carpenter',
#                'Sam Smith',
#                'Saweetie',
#                'Sean Paul',
#                'Sech',
#                'Seezyn',
#                'Selena Gomez',
#                'Shakira',
#                'Shawn Mendes',
#                'Sia',
#                'Skepta',
#                'Ski Mask The Slump God',
#                'Skylar Grey',
#                'Snoop Dogg',
#                'Snow',
#                'Social House',
#                'Stunna 4 Vegas',
#                'Summer Walker',
#                'Swae Lee',
#                'T-Pain',
#                'THE SCOTTS',
#                'Tainy',
#                'Taylor Swift',
#                'The Chainsmokers',
#                'The Creator',
#                'The Kid LAROI',
#                'The National',
#                'The Neptunes',
#                'The Weeknd',
#                'Tory Lanez',
#                'Travis Barker',
#                'Travis Scott',
#                'Trevor Daniel',
#                'Trippie Redd',
#                'Troye Sivan',
#                'Ty Dolla $ign',
#                'Tyga',
#                'Tyla Yaweh',
#                'Tyler',
#                'Usher',
#                'White Gold',
#                'Wisin',
#                'Wiz Khalifa',
#                'WizKid',
#                'Wyclef Jean',
#                'X Ambassadors',
#                'XXXTENTACION',
#                'YNW Melly',
#                'YUNGBLUD',
#                'Yak Gotti',
#                'Yandel',
#                'Yaviah',
#                'Young Stoner Life',
#                'Young Thug',
#                'YoungBoy Never Broke Again',
#                'Yung Bleu',
#                'ZAYN',
#                'Zacari',
#                'Zedd',
#                'Zion',
#                'benny blanco',
#                'blackbear',
#                'iann dior',
#                'watt',
#                'Ángela Aguilar',
#                'Ñengo Flow'},
#               {'Blueface', 'DDG'},
#               {'A7S', 'Topic'},
#               {'ジミー',
#                '加島優',
#                '明美圭一',
#                '田村唯',
#                '百合絢斗',
#                '矢口恭介',
#                '糸目幸士郎',
#                '遠野高志',
#                '鹿谷樹'},
#               {'Cali Y El Dandee', 'Danna Paola'},
#               {'Mitchell Ayres & His Orchestra',
#                'Perry Como',
#                'The Fontane Sisters'},
#               {'RANI', 'Sam Feldt'},
#               {'John Williams', 'Mykola Dmytrovych Leontovych'},
#               {'Fetty Wap', 'Remy Boyz'},
#               {'D.O.E.',
#                'Justin Timberlake',
#                'Keri Hilson',
#                'Nelly Furtado',
#                'Timbaland'},
#               {'Blake Shelton', 'Gwen Stefani'},
#               {'Y2K', 'bbno$'},
#               {'Adriana Proenza', 'Kina', 'Snøw'},
#               {'(G)I-DLE',
#                'Against The Current',
#                'Bea Miller',
#                'Jaira Burns',
#                'K/DA',
#                'Kim Petras',
#                'League of Legends',
#                'Lexie Liu',
#                'Madison Beer',
#                'Seraphine',
#                'Wolftyla'},
#               {'Daniel Hope', 'I Virtuosi Italiani', 'Ludovico Einaudi'},
#               {'Beltito', 'Osquel', 'Sammy & Falsetto', 'Super Yei', 'Towy'},
#               {'Au/Ra', 'Jax Jones'},
#               {'Conrad Sewell', 'Kygo', 'OneRepublic', 'Whitney Houston'},
#               {'Sista Prod', 'Subvrbs'},
#               {'Mike Taylor', 'Unlike Pluto'},
#               {'Keith Urban', 'Nate Ruess', 'P!nk'},
#               {'Keala Settle', 'The Greatest Showman Ensemble'},
#               {'Clairo', 'Wallows'},
#               {'John Lennon', 'Yoko Ono'},
#               {'JP Saxe', 'Julia Michaels'},
#               {'Adam Levine', 'Gym Class Heroes'},
#               {'CORPSE', 'Savage Ga$p'},
#               {'Brett Eldredge',
#                'Gary Clark Jr.',
#                'John Legend',
#                'Meghan Trainor'},
#               {'Aloe Blacc', 'Avicii', 'Sandro Cavazza'},
#               {'Chris Linton', 'Lost Sky'},
#               {'Kirsty MacColl', 'The Pogues'},
#               {'Francesco Yates', 'KIDDO', 'Robin Schulz'},
#               {'John Martin', 'Swedish House Mafia'},
#               {'Marvin Gaye', 'Tammi Terrell'},
#               {'Kelly Rowland', 'Nelly'},
#               {'FLETCHER', 'Kito'},
#               {'Ali Gatie', 'Tate McRae'},
#               {'BENEE', 'Gus Dapperton'},
#               {'Grupo Firme', 'Lenin Ramírez', 'Marca MP'},
#               {'Shiloh Dynasty', 'itssvd'},
#               {'REI AMI', 'Sub Urban'},
#               {'Curtis Waters', 'Harm Franklin'},
#               {'Powfu', 'beabadoobee'},
#               {'Ashe', 'Niall Horan'},
#               {'Zac Efron', 'Zendaya'},
#               {'B. Swanson Quartet', 'Frank Sinatra'},
#               {'America', 'George Martin'},
#               {'Coolio', 'L.V.'},
#               {'Norma Jean Martine', 'Ofenbach', 'Quarterhead'},
#               {'Bing Crosby',
#                'John Scott Trotter & His Orchestra',
#                'Ken Darby Singers'},
#               {'$NOT', 'CADE', 'Cheat Codes', 'Maggie Lindemann'},
#               {'Erik Eriksson',
#                'White Noise Baby Sleep',
#                'White Noise for Babies'},
#               {'AURORA', 'Idina Menzel', 'Michael Bublé'},
#               {'J. Davi$', 'Rob $tone', 'Spooks'},
#               {'Mac Miller', 'Miguel'},
#               {'2Pac', 'Big Syke'},
#               {'"Cookin On 3 Burners"', 'Kungs'},
#               {'Emilee', 'Surf Mesa'},
#               {'Benny Sings', 'Rex Orange County'},
#               {'El Fantasma', 'Los Dos Carnales'},
#               {'"Olivia OBrien"', 'gnash'},
#               {'Guaynaa', 'Lele Pons', 'Sebastian Yatra'},
#               {'Felix Jaehn', 'Nea'},
#               {'Peachy!', 'mxmtoon'},
#               {'A Great Big World', 'Christina Aguilera'},
#               {'MAX', 'SUGA'},
#               {'Chelsea Cutler', 'Jeremy Zucker', 'Quinn XCII'},
#               {'Annie Lennox', 'Dave Stewart', 'Eurythmics'},
#               {'Aaron Smith', 'Krono', 'Luvli'},
#               {'Billy Ray Cyrus', 'Lil Nas X'},
#               {'Sammie', 'Soulja Boy'},
#               {'Jubël', 'NEIMY'},
#               {'Bill Withers', 'Grover Washington', 'Jr.'},
#               {'Dylan Matthew', 'SLANDER'},
#               {'Joel Corry', 'MNEK'},
#               {'"Gigi DAgostino"', 'Dynoro'},
#               {'James Arthur', 'Sigala'},
#               {'MC Virgins', 'Yun Head'},
#               {'Rik Rok', 'Shaggy'}],
#              2: [{'Becky Hill', 'Goodboys', 'MEDUZA'},
#               {'2 Chainz',
#                '21 Savage',
#                '24kGoldn',
#                '50 Cent',
#                'A Boogie Wit da Hoodie',
#                'A$AP Rocky',
#                'Alessia Cara',
#                'Alesso',
#                'Alicia Keys',
#                'Anne-Marie',
#                'Anuel AA',
#                'Arcangel',
#                'Ariana Grande',
#                'Bad Bunny',
#                'Bebe Rexha',
#                'Big Sean',
#                'Brendon Urie',
#                'Bruno Mars',
#                'Bryant Myers',
#                'Calvin Harris',
#                'Camila Cabello',
#                'Camilo',
#                'Cardi B',
#                'Casper Magico',
#                'Cazzu',
#                'Chance the Rapper',
#                'Chencho Corleone',
#                'Chris Brown',
#                'DJ Nelson',
#                'DJ Snake',
#                'DaBaby',
#                'Daddy Yankee',
#                'Daft Punk',
#                'Darell',
#                'Dixie D’Amelio',
#                'Doja Cat',
#                'Don Toliver',
#                'Drake',
#                'Dua Lipa',
#                'Ed Sheeran',
#                'Ellie Goulding',
#                'Eminem',
#                'Farruko',
#                'Florida Georgia Line',
#                'Future',
#                'G-Eazy',
#                'Grey',
#                'Gunna',
#                'H.E.R.',
#                'Hailee Steinfeld',
#                'Halsey',
#                'Imagine Dragons',
#                'Imanbek',
#                'Internet Money',
#                'J Balvin',
#                'JACKBOYS',
#                'JAY-Z',
#                'Jack Harlow',
#                'Jay Wheeler',
#                'Jhay Cortez',
#                'Jhené Aiko',
#                'Juice WRLD',
#                'Justin Bieber',
#                'KAROL G',
#                'KEVVO',
#                'Kacey Musgraves',
#                'Kane Brown',
#                'Kanye West',
#                'Kendo Kaponi',
#                'Kendrick Lamar',
#                'Khalid',
#                'Kid Cudi',
#                'King Von',
#                'Kodak Black',
#                'Lauv',
#                'Lenny Tavárez',
#                'Liam Payne',
#                'Lil Baby',
#                'Lil Durk',
#                'Lil Jon',
#                'Lil Mosey',
#                'Lil Tecca',
#                'Lil Tjay',
#                'Lil Uzi Vert',
#                'Lil Wayne',
#                'Logic',
#                'Ludacris',
#                'Lunay',
#                'Lyanno',
#                'Machine Gun Kelly',
#                'Macklemore',
#                'Maluma',
#                'Maren Morris',
#                'Mark Ronson',
#                'Marshmello',
#                'Martin Garrix',
#                'Megan Thee Stallion',
#                'Metro Boomin',
#                'Mustard',
#                'Myke Towers',
#                'NAV',
#                'NLE Choppa',
#                'Nicki Minaj',
#                'Nicky Jam',
#                'Nio Garcia',
#                'Offset',
#                'Ozuna',
#                'Ozzy Osbourne',
#                'Pharrell Williams',
#                'Polo G',
#                'Pop Smoke',
#                'Post Malone',
#                'Quavo',
#                'ROSALÍA',
#                'Rauw Alejandro',
#                'Rihanna',
#                'Roddy Ricch',
#                'Romeo Santos',
#                'SZA',
#                'Saweetie',
#                'Sean Paul',
#                'Sech',
#                'Selena Gomez',
#                'Shawn Mendes',
#                'Sia',
#                'Skepta',
#                'Skylar Grey',
#                'Stunna 4 Vegas',
#                'Swae Lee',
#                'Tainy',
#                'Taylor Swift',
#                'The Chainsmokers',
#                'The Kid LAROI',
#                'The Neptunes',
#                'The Weeknd',
#                'Tory Lanez',
#                'Travis Scott',
#                'Trippie Redd',
#                'Troye Sivan',
#                'Ty Dolla $ign',
#                'Tyga',
#                'Usher',
#                'Wiz Khalifa',
#                'X Ambassadors',
#                'XXXTENTACION',
#                'Young Thug',
#                'YoungBoy Never Broke Again',
#                'ZAYN',
#                'Zedd',
#                'benny blanco',
#                'blackbear',
#                'iann dior'},
#               {'(G)I-DLE',
#                'Bea Miller',
#                'Jaira Burns',
#                'K/DA',
#                'Kim Petras',
#                'League of Legends',
#                'Lexie Liu',
#                'Madison Beer',
#                'Seraphine',
#                'Wolftyla'}],
#              3: [{'24kGoldn',
#                'Anuel AA',
#                'Ariana Grande',
#                'Bad Bunny',
#                'Camila Cabello',
#                'Cardi B',
#                'Chris Brown',
#                'DJ Nelson',
#                'DaBaby',
#                'Daddy Yankee',
#                'Darell',
#                'Doja Cat',
#                'Drake',
#                'Dua Lipa',
#                'Ed Sheeran',
#                'Farruko',
#                'Gunna',
#                'Halsey',
#                'J Balvin',
#                'Jhay Cortez',
#                'Juice WRLD',
#                'Justin Bieber',
#                'KAROL G',
#                'Khalid',
#                'Lil Baby',
#                'Machine Gun Kelly',
#                'Marshmello',
#                'Megan Thee Stallion',
#                'Metro Boomin',
#                'Myke Towers',
#                'Nicki Minaj',
#                'Nicky Jam',
#                'Ozuna',
#                'Polo G',
#                'Pop Smoke',
#                'Post Malone',
#                'ROSALÍA',
#                'Rauw Alejandro',
#                'Sech',
#                'Tainy',
#                'The Kid LAROI',
#                'The Weeknd',
#                'Travis Scott',
#                'Trippie Redd',
#                'Ty Dolla $ign',
#                'Young Thug',
#                'benny blanco',
#                'iann dior'}]})

# %%
apxa.max_clique(G)
# Out:
# {'JAY-Z', 'Kanye West', 'Rihanna'}

# %%
betweennss = nx.betweenness_centrality(G)
G = add_attributes(G,betweennss ,'betweennes_value')

# %%
closennes = nx.closeness_centrality(G)
G = add_attributes(G,closennes ,'closeness_value')
# Out:
# {"Gigi D'Agostino": 0.0,
#  "Cookin' On 3 Burners": 0.0,
#  "Olivia O'Brien": 0.0,
#  'Grover Washington, Jr.': 0.0,
#  'Tyler, The Creator': 0.0,
#  'DDG': 0.0019083969465648854,
#  'A7S': 0.0019083969465648854,
#  'Cali Y El Dandee': 0.0019083969465648854,
#  'Sam Feldt': 0.0019083969465648854,
#  'Mykola Dmytrovych Leontovych': 0.0019083969465648854,
#  'Remy Boyz': 0.0019083969465648854,
# %%
voterank=nx.voterank(G)
G = add_attributes(G,closennes ,'voterank_value')

# %%
from networkx.algorithms import community
communities_generator =community.label_propagation_communities(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
sorted( top_level_communities)
# Out:
# ['Clean Bandit', 'Sean Paul']

# %% [raw]
# import community as community_louvain
# import matplotlib.cm as cm
# import matplotlib.pyplot as plt
# import networkx as nx
#
# #first compute the best partition
# partition = community_louvain.best_partition(G)
#
# # compute the best partition
# partition = community_louvain.best_partition(G)
#
# # draw the graph
# pos = nx.spring_layout(G)
# # color the nodes according to their partition
# cmap = cm.get_cmap('viridis', max(partition.values()) + 1)
# nx.draw_networkx_nodes(G, pos, partition.keys(), node_size=40,
#                        cmap=cmap, node_color=list(partition.values()))
# nx.draw_networkx_edges(G, pos, alpha=0.5)
# plt.show()

# %%
from networkx.readwrite import json_graph

print json_graph.dumps(G)
# Out:
#   File "<ipython-input-13-839510a45d55>", line 3
#     print json_graph.dumps(G)
#                    ^
# SyntaxError: invalid syntax

# %% [raw]
# g = Network()
# g.from_nx(G)
# g.show_buttons(filter_=['physics'])

# %%
central=nx.voterank(G)

# %%
central
# Out:
# ['Juice WRLD',
#  'Bad Bunny',
#  'Drake',
#  'J Balvin',
#  'Myke Towers',
#  'Lil Baby',
#  'Justin Bieber',
#  'Travis Scott',
#  'Marshmello',
#  'Ariana Grande',
#  'Wiz Khalifa',
#  'Rauw Alejandro',
#  'DaBaby',
#  'Doja Cat',
#  'Post Malone',
#  'Kanye West',
#  'Pop Smoke',
#  '(G)I-DLE',
#  'Macklemore',
#  'Halsey',
#  'Daddy Yankee',
#  'Diplo',
#  'Ty Dolla $ign',
#  'The Chainsmokers',
#  'League of Legends',
#  'Taylor Swift',
#  'Calvin Harris',
#  'Gunna',
#  'Khalid',
#  'Ozuna',
#  'Lil Uzi Vert',
#  'Eminem',
#  'Usher',
#  'The Kid LAROI',
#  'Polo G',
#  'Jason Derulo',
#  'Timbaland',
#  'Pharrell Williams',
#  'Grey',
#  'MEDUZA',
#  'Kygo',
#  'Lyanno',
#  'Young Thug',
#  'Anuel AA',
#  'Kendrick Lamar',
#  'Dua Lipa',
#  'Piso 21',
#  'H.E.R.',
#  'Selena Gomez',
#  'XXXTENTACION',
#  'Lauv',
#  'Shakira',
#  'Alesso',
#  'NLE Choppa',
#  'Tory Lanez',
#  'Skepta',
#  '加島優',
#  'The Fontane Sisters',
#  'Farruko',
#  'Pitbull',
#  'Sam Smith',
#  'Osquel',
#  'Kina',
#  '明美圭一',
#  'Robin Schulz',
#  'Meghan Trainor',
#  'Quarterhead',
#  'RAYE',
#  'Grupo Firme',
#  'White Noise Baby Sleep',
#  'Idina Menzel',
#  'J. Davi$',
#  'Maggie Lindemann',
#  'Guaynaa',
#  'Chelsea Cutler',
#  'Daniel Hope',
#  'P!nk',
#  'Krono',
#  'Avicii',
#  'Bryant Myers',
#  'Annie Lennox',
#  'Ken Darby Singers',
#  'Jr.',
#  'The Creator',
#  'Camila Cabello',
#  'Lenny Tavárez',
#  'Machine Gun Kelly',
#  'Nio Garcia',
#  'Logic',
#  'Mark Ronson',
#  'Sech',
#  'Sia',
#  'Alan Walker',
#  'Afrojack',
#  'Don Toliver',
#  '百合絢斗',
#  'Maren Morris',
#  'Lil Durk',
#  'Swae Lee',
#  'Rihanna',
#  'Florida Georgia Line',
#  'Madison Beer',
#  'Mustard',
#  'Offset',
#  'Sean Paul',
#  'Jaira Burns',
#  'DDG',
#  'A7S',
#  'Cali Y El Dandee',
#  'Sam Feldt',
#  'Mykola Dmytrovych Leontovych',
#  'Remy Boyz',
#  'Gwen Stefani',
#  'bbno$',
#  'Au/Ra',
#  'Sista Prod',
#  'Mike Taylor',
#  'The Greatest Showman Ensemble',
#  'Wallows',
#  'Yoko Ono',
#  'Julia Michaels',
#  'Adam Levine',
#  'CORPSE',
#  'Chris Linton',
#  'Kirsty MacColl',
#  'John Martin',
#  'Marvin Gaye',
#  'Kelly Rowland',
#  'Christian Nodal',
#  'FLETCHER',
#  'Ali Gatie',
#  'Gus Dapperton',
#  'itssvd',
#  'Lil Peep',
#  'REI AMI',
#  'Curtis Waters',
#  'beabadoobee',
#  'Niall Horan',
#  'YUNGBLUD',
#  'Keri Hilson',
#  'Zendaya',
#  'B. Swanson Quartet',
#  'America',
#  'Coolio',
#  'Alex Rose',
#  'Mac Miller',
#  'A Boogie Wit da Hoodie',
#  'Lady Gaga',
#  'Summer Walker',
#  'Big Syke',
#  'Brray',
#  'Kungs',
#  'Labrinth',
#  'John Legend',
#  'Emilee',
#  'Snoop Dogg',
#  'Rex Orange County',
#  'El Fantasma',
#  'gnash',
#  'Towy',
#  'Nea',
#  'Camilo',
#  'WizKid',
#  'mxmtoon',
#  'Christina Aguilera',
#  'Flo Rida',
#  'Masego',
#  'Jowell & Randy',
#  'Megan Thee Stallion',
#  'SUGA',
#  'Beltito',
#  'Arcangel',
#  '50 Cent',
#  'Lil Nas X',
#  'Soulja Boy',
#  'Jubël',
#  'blackbear',
#  'Lil Wayne',
#  'Brendon Urie',
#  'Dylan Matthew',
#  'Joel Corry',
#  'Dynoro',
#  'Sigala',
#  'ILLENIUM',
#  'Yun Head',
#  'Cheat Codes',
#  'Rik Rok',
#  '糸目幸士郎',
#  'Social House',
#  'Lunay',
#  'Goodboys',
#  'Chencho Corleone',
#  'Kali Uchis',
#  'Liam Payne',
#  'Troye Sivan',
#  'JAY-Z',
#  'Rudimental',
#  'Bea Miller',
#  'Trippie Redd',
#  'The Weeknd',
#  'Imagine Dragons',
#  'DJ Nelson',
#  'Lil Jon',
#  'Metro Boomin',
#  '矢口恭介',
#  'SZA',
#  'Saweetie',
#  'Jack Harlow',
#  'Bebe Rexha',
#  'Zedd',
#  'iann dior',
#  'YoungBoy Never Broke Again',
#  'Nicki Minaj',
#  'Darell']

# %%
center_nodes=['Juice WRLD',
 'Bad Bunny',
 'Drake',
 'J Balvin',
 'Myke Towers',
 'Lil Baby',
 'Justin Bieber',
 'Travis Scott',
 'Marshmello',
 'Wiz Khalifa',
 'Ariana Grande',
 'DaBaby',
 'Rauw Alejandro',
 'Doja Cat',
 'Post Malone']
voronoi=nx.voronoi_cells(G,center_nodes)

# %%
voronoi
# Out:
# {'Juice WRLD': {'BTS',
#   'Bankrol Hayden',
#   'Bon Iver',
#   'Brendon Urie',
#   'Calvin Harris',
#   'Coldplay',
#   'Daft Punk',
#   'Dan Caplen',
#   'Daya',
#   'Dido',
#   'Disciples',
#   'Ellie Goulding',
#   'Eminem',
#   'Fall Out Boy',
#   'Funk Wav',
#   'Future',
#   'G Herbo',
#   'G-Eazy',
#   'HAIM',
#   'Halsey',
#   'ILLENIUM',
#   'Internet Money',
#   'Jess Glynne',
#   'Jessie Reyez',
#   'Juice WRLD',
#   'Kelsea Ballerini',
#   'King Von',
#   'Lennon Stella',
#   'Lil Mosey',
#   'Lil Peep',
#   'Lil Tecca',
#   'Lil Tjay',
#   'Lil Tracy',
#   'Lil Uzi Vert',
#   'M.I.A.',
#   'Machine Gun Kelly',
#   'Macklemore',
#   'Nate Dogg',
#   'Normani',
#   'Oh Wonder',
#   'Panic! At The Disco',
#   'Playboi Carti',
#   'Polo G',
#   'Popp Hunna',
#   'RAYE',
#   'Regard',
#   'Rudimental',
#   'Sam Smith',
#   'Seezyn',
#   'Ski Mask The Slump God',
#   'Skylar Grey',
#   'Stunna 4 Vegas',
#   'Taylor Swift',
#   'The Chainsmokers',
#   'The Kid LAROI',
#   'The National',
#   'The Weeknd',
#   'Travis Barker',
#   'Trippie Redd',
#   'White Gold',
#   'XXXTENTACION',
#   'YNW Melly',
#   'YUNGBLUD',
#   'Young Stoner Life',
#   'Young Thug',
#   'YoungBoy Never Broke Again',
#   'benny blanco'},
#  'Bad Bunny': {'ABRA',
#   'Anuel AA',
#   'Arcangel',
#   'Bad Bunny',
#   'Cardi B',
#   'Casper Magico',
#   'Clean Bandit',
#   'Daddy Yankee',
#   'Darell',
#   'Dua Lipa',
#   'Dímelo Flow',
#   'Flow La Movie',
#   'Jhay Cortez',
#   'Jowell & Randy',
#   'Kendo Kaponi',
#   'Luis Fonsi',
#   'Lunay',
#   'Marc Anthony',
#   'Martin Garrix',
#   'Miley Cyrus',
#   'Mora',
#   'Nio Garcia',
#   'ROSALÍA',
#   'Romeo Santos',
#   'Sean Paul',
#   'Sech',
#   'Snow',
#   'Tainy',
#   'Yandel',
#   'Yaviah',
#   'Zion',
#   'Ñengo Flow'},
#  'Drake': {'2 Chainz',
#   '6ix9ine',
#   'A Boogie Wit da Hoodie',
#   'A$AP Rocky',
#   'Alicia Keys',
#   'Bryson Tiller',
#   'Chris Brown',
#   'DJ Khaled',
#   'Daniel Caesar',
#   'Drake',
#   'Dwele',
#   'Estelle',
#   'Giveon',
#   'H.E.R.',
#   'JAY-Z',
#   'Jamie Foxx',
#   'Jay Rock',
#   'Kali Uchis',
#   'Kanye West',
#   'Kendrick Lamar',
#   'Kyla',
#   'Lil Durk',
#   'Meek Mill',
#   'Metro Boomin',
#   'Octavian',
#   'PARTYNEXTDOOR',
#   'Paul McCartney',
#   'Pooh Shiesty',
#   'Rick Ross',
#   'Rihanna',
#   'Roy Woods',
#   'Skepta',
#   'Summer Walker',
#   'The Creator',
#   'Tyler',
#   'WizKid',
#   'Yung Bleu',
#   'Zacari'},
#  'J Balvin': {'Black Eyed Peas',
#   'Bryant Myers',
#   'Chencho Corleone',
#   'El Guincho',
#   'Freshlyground',
#   'J Balvin',
#   'KAROL G',
#   'KEVVO',
#   'Kevin Roldan',
#   'Ozuna',
#   'Shakira',
#   'Wyclef Jean',
#   'iann dior'},
#  'Myke Towers': {'Alan Walker',
#   'Ava Max',
#   'Brray',
#   'Christian Nodal',
#   'DJ Nelson',
#   'Farruko',
#   'Jay Wheeler',
#   'Juanka',
#   'Juhn',
#   'Los Legendarios',
#   'Maluma',
#   'Micro TDH',
#   'Myke Towers',
#   'Nicky Jam',
#   'Piso 21',
#   'Sabrina Carpenter',
#   'Wisin',
#   'Ángela Aguilar'},
#  'Lil Baby': {'42 Dugg',
#   '50 Cent',
#   'Don Toliver',
#   'FKJ',
#   'Gunna',
#   'Jack Harlow',
#   'Lil Baby',
#   'Masego',
#   'Money Man',
#   'Moneybagg Yo',
#   'NAV',
#   'Olivia',
#   'Pop Smoke',
#   'Rod Wave',
#   'Yak Gotti'},
#  'Justin Bieber': {'24kGoldn',
#   'Chance the Rapper',
#   'DJ Snake',
#   'Dan + Shay',
#   'Ed Sheeran',
#   'Justin Bieber',
#   'Lil Jon',
#   'Ludacris',
#   'Quavo',
#   'Shawn Mendes'},
#  'Travis Scott': {'HVME',
#   'JACKBOYS',
#   'Kacy Hill',
#   'Kid Cudi',
#   'Kodak Black',
#   'Offset',
#   'Ozzy Osbourne',
#   'SZA',
#   'THE SCOTTS',
#   'The Neptunes',
#   'Travis Scott',
#   'Tyga'},
#  'Marshmello': {'Afrojack',
#   'Alessia Cara',
#   'Anne-Marie',
#   'BLACKPINK',
#   'Bastille',
#   'Becky Hill',
#   'Billie Eilish',
#   'CHVRCHES',
#   'Conan Gray',
#   'Demi Lovato',
#   'Dermot Kennedy',
#   'Disclosure',
#   'Goodboys',
#   'Grey',
#   'Hozier',
#   'Imanbek',
#   'Kane Brown',
#   'Kesha',
#   'Khalid',
#   'Lauv',
#   'MEDUZA',
#   'Maren Morris',
#   'Marshmello',
#   'Nayer',
#   'Ne-Yo',
#   'Pitbull',
#   'Selena Gomez',
#   'Trevor Daniel',
#   'Troye Sivan',
#   'Usher',
#   'Zedd'},
#  'Wiz Khalifa': {'Alesso',
#   'All Time Low',
#   'Bruno Mars',
#   'Charlie Puth',
#   'Dixie D’Amelio',
#   'Dr. Dre',
#   'Hailee Steinfeld',
#   'Imagine Dragons',
#   'Jay Sean',
#   'Kacey Musgraves',
#   'Liam Payne',
#   'Lil Wayne',
#   'Mark Ronson',
#   'Migos',
#   'Mustard',
#   'Snoop Dogg',
#   'Wiz Khalifa',
#   'X Ambassadors',
#   'blackbear'},
#  'Ariana Grande': {'Ariana Grande',
#   'Bradley Cooper',
#   'Fifth Harmony',
#   'Jason Derulo',
#   'Jawsh 685',
#   'Jessie J',
#   'Kehlani',
#   'Lady Gaga',
#   'Lil Yachty',
#   'Little Mix',
#   'Liz Gillies',
#   'Lizzo',
#   'Logic',
#   'Nicki Minaj',
#   'Nile Rodgers',
#   'Nuka',
#   'Pharrell Williams',
#   'Social House',
#   'Ty Dolla $ign'},
#  'DaBaby': {'Bazzi',
#   'Beyoncé',
#   'Camila Cabello',
#   'DaBaby',
#   'Megan Thee Stallion',
#   'Mike WiLL Made-It',
#   'NLE Choppa',
#   'Roddy Ricch',
#   'Tory Lanez'},
#  'Rauw Alejandro': {'Alex Rose',
#   'Camilo',
#   'Cazzu',
#   'Dalex',
#   'El Alfa',
#   'Ir Sais',
#   'Justin Quiles',
#   'Lenny Tavárez',
#   'Lyanno',
#   'Manuel Turizo',
#   'Rafa Pabön',
#   'Rauw Alejandro'},
#  'Doja Cat': {'Bebe Rexha',
#   'City Girls',
#   'Diplo',
#   'Doja Cat',
#   'Flo Rida',
#   'Florida Georgia Line',
#   'Gucci Mane',
#   'Jhené Aiko',
#   'Joji',
#   'Jonas Brothers',
#   'LSD',
#   'Labrinth',
#   'Morgan Wallen',
#   'Saweetie',
#   'Sia',
#   'T-Pain',
#   'ZAYN',
#   'watt'},
#  'Post Malone': {'21 Savage',
#   'Big Sean',
#   'French Montana',
#   'Post Malone',
#   'Swae Lee',
#   'Tyla Yaweh'},
#  'unreachable': {'"Cookin On 3 Burners"',
#   '"Gigi DAgostino"',
#   '"Olivia OBrien"',
#   '$NOT',
#   '(G)I-DLE',
#   '2Pac',
#   'A Great Big World',
#   'A7S',
#   'AURORA',
#   'Aaron Smith',
#   'Adam Levine',
#   'Adriana Proenza',
#   'Against The Current',
#   'Ali Gatie',
#   'Aloe Blacc',
#   'America',
#   'Annie Lennox',
#   'Ashe',
#   'Au/Ra',
#   'Avicii',
#   'B. Swanson Quartet',
#   'BENEE',
#   'Bea Miller',
#   'Beltito',
#   'Benny Sings',
#   'Big Syke',
#   'Bill Withers',
#   'Billy Ray Cyrus',
#   'Bing Crosby',
#   'Blake Shelton',
#   'Blueface',
#   'Brett Eldredge',
#   'CADE',
#   'CORPSE',
#   'Cali Y El Dandee',
#   'Cheat Codes',
#   'Chelsea Cutler',
#   'Chris Linton',
#   'Christina Aguilera',
#   'Clairo',
#   'Conrad Sewell',
#   "Cookin' On 3 Burners",
#   'Coolio',
#   'Curtis Waters',
#   'D.O.E.',
#   'DDG',
#   'Daniel Hope',
#   'Danna Paola',
#   'Dave Stewart',
#   'Dylan Matthew',
#   'Dynoro',
#   'El Fantasma',
#   'Emilee',
#   'Erik Eriksson',
#   'Eurythmics',
#   'FLETCHER',
#   'Felix Jaehn',
#   'Fetty Wap',
#   'Francesco Yates',
#   'Frank Sinatra',
#   'Gary Clark Jr.',
#   'George Martin',
#   "Gigi D'Agostino",
#   'Grover Washington',
#   'Grover Washington, Jr.',
#   'Grupo Firme',
#   'Guaynaa',
#   'Gus Dapperton',
#   'Gwen Stefani',
#   'Gym Class Heroes',
#   'Harm Franklin',
#   'I Virtuosi Italiani',
#   'Idina Menzel',
#   'J. Davi$',
#   'JP Saxe',
#   'Jaira Burns',
#   'James Arthur',
#   'Jax Jones',
#   'Jeremy Zucker',
#   'Joel Corry',
#   'John Legend',
#   'John Lennon',
#   'John Martin',
#   'John Scott Trotter & His Orchestra',
#   'John Williams',
#   'Jr.',
#   'Jubël',
#   'Julia Michaels',
#   'Justin Timberlake',
#   'K/DA',
#   'KIDDO',
#   'Keala Settle',
#   'Keith Urban',
#   'Kelly Rowland',
#   'Ken Darby Singers',
#   'Keri Hilson',
#   'Kim Petras',
#   'Kina',
#   'Kirsty MacColl',
#   'Kito',
#   'Krono',
#   'Kungs',
#   'Kygo',
#   'L.V.',
#   'League of Legends',
#   'Lele Pons',
#   'Lenin Ramírez',
#   'Lexie Liu',
#   'Lil Nas X',
#   'Los Dos Carnales',
#   'Lost Sky',
#   'Ludovico Einaudi',
#   'Luvli',
#   'MAX',
#   'MC Virgins',
#   'MNEK',
#   'Mac Miller',
#   'Madison Beer',
#   'Maggie Lindemann',
#   'Marca MP',
#   'Marvin Gaye',
#   'Meghan Trainor',
#   'Michael Bublé',
#   'Miguel',
#   'Mike Taylor',
#   'Mitchell Ayres & His Orchestra',
#   'Mykola Dmytrovych Leontovych',
#   'NEIMY',
#   'Nate Ruess',
#   'Nea',
#   'Nelly',
#   'Nelly Furtado',
#   'Niall Horan',
#   'Norma Jean Martine',
#   'Ofenbach',
#   "Olivia O'Brien",
#   'OneRepublic',
#   'Osquel',
#   'P!nk',
#   'Peachy!',
#   'Perry Como',
#   'Powfu',
#   'Quarterhead',
#   'Quinn XCII',
#   'RANI',
#   'REI AMI',
#   'Remy Boyz',
#   'Rex Orange County',
#   'Rik Rok',
#   'Rob $tone',
#   'Robin Schulz',
#   'SLANDER',
#   'SUGA',
#   'Sam Feldt',
#   'Sammie',
#   'Sammy & Falsetto',
#   'Sandro Cavazza',
#   'Savage Ga$p',
#   'Sebastian Yatra',
#   'Seraphine',
#   'Shaggy',
#   'Shiloh Dynasty',
#   'Sigala',
#   'Sista Prod',
#   'Snøw',
#   'Soulja Boy',
#   'Spooks',
#   'Sub Urban',
#   'Subvrbs',
#   'Super Yei',
#   'Surf Mesa',
#   'Swedish House Mafia',
#   'Tammi Terrell',
#   'Tate McRae',
#   'The Fontane Sisters',
#   'The Greatest Showman Ensemble',
#   'The Pogues',
#   'Timbaland',
#   'Topic',
#   'Towy',
#   'Tyler, The Creator',
#   'Unlike Pluto',
#   'Wallows',
#   'White Noise Baby Sleep',
#   'White Noise for Babies',
#   'Whitney Houston',
#   'Wolftyla',
#   'Y2K',
#   'Yoko Ono',
#   'Yun Head',
#   'Zac Efron',
#   'Zendaya',
#   'bbno$',
#   'beabadoobee',
#   'gnash',
#   'itssvd',
#   'mxmtoon',
#   'ジミー',
#   '加島優',
#   '明美圭一',
#   '田村唯',
#   '百合絢斗',
#   '矢口恭介',
#   '糸目幸士郎',
#   '遠野高志',
#   '鹿谷樹'}}

# %%
import json

import flask
import networkx as nx
from networkx.readwrite import json_graph
d = json_graph.node_link_data(G)  # node-link format to serialize
# write json
#json.dump(d, open("../data/force.json", "w"))
#print("Wrote node-link JSON data to force/force.json")

# Serve the file over http to allow for cross origin requests
#app = flask.Flask(__name__, static_folder="force")


#@app.route("/")
#def static_proxy():
#    return app.send_static_file("force.html")


#print("\nGo to http://localhost:8000 to see the example\n")
#app.run(port=8000)
